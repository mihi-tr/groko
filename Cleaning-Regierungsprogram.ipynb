# %%
f=open("data/regierungsprogramm 2013 - 2018s.html")
data=f.read()
f.close()

# %%
data[0:10000]
# Out:
# '<!DOCTYPE html><html>\n<head>\n<title></title>\n<style type="text/css">\n<!--\n.xflip {\n    -moz-transform: scaleX(-1);\n    -webkit-transform: scaleX(-1);\n    -o-transform: scaleX(-1);\n    transform: scaleX(-1);\n    filter: fliph;\n}\n.yflip {\n    -moz-transform: scaleY(-1);\n    -webkit-transform: scaleY(-1);\n    -o-transform: scaleY(-1);\n    transform: scaleY(-1);\n    filter: flipv;\n}\n.xyflip {\n    -moz-transform: scaleX(-1) scaleY(-1);\n    -webkit-transform: scaleX(-1) scaleY(-1);\n    -o-transform: scaleX(-1) scaleY(-1);\n    transform: scaleX(-1) scaleY(-1);\n    filter: fliph + flipv;\n}\n-->\n</style>\n</head>\n<body>\n<a name=1></a><b>Erfolgreich.&#160;\xc3\x96sterreich.</b><br/>\n<b>Arbeitsprogramm&#160;der&#160;\xc3\xb6sterreichischen&#160;</b><br/>\n<b>Bundesregierung&#160;f\xc3\xbcr&#160;die&#160;Jahre&#160;</b><br/>\n<b>2013&#160;bis&#160;2018</b><br/>\n1<br/>\n<hr/>\n<a name=2></a><b>Inhaltsverzeichnis</b><br/>\n<b>Pr\xc3\xa4ambel</b><br/>\n<b>Seite&#160;<
# ...

# %%
data=data.replace("&#160;"," ")

# %%
import re

# %%
re.sub("a","b","aaccadd")
# Out:
# 'bbccbdd'

# %%
data=re.sub("\\n[0-9]+\<br/\>","",data)

# %%
data.replace("<hr/>","")
# Out:
# '<!DOCTYPE html><html>\n<head>\n<title></title>\n<style type="text/css">\n<!--\n.xflip {\n    -moz-transform: scaleX(-1);\n    -webkit-transform: scaleX(-1);\n    -o-transform: scaleX(-1);\n    transform: scaleX(-1);\n    filter: fliph;\n}\n.yflip {\n    -moz-transform: scaleY(-1);\n    -webkit-transform: scaleY(-1);\n    -o-transform: scaleY(-1);\n    transform: scaleY(-1);\n    filter: flipv;\n}\n.xyflip {\n    -moz-transform: scaleX(-1) scaleY(-1);\n    -webkit-transform: scaleX(-1) scaleY(-1);\n    -o-transform: scaleX(-1) scaleY(-1);\n    transform: scaleX(-1) scaleY(-1);\n    filter: fliph + flipv;\n}\n-->\n</style>\n</head>\n<body>\n<a name=1></a><b>Erfolgreich. \xc3\x96sterreich.</b><br/>\n<b>Arbeitsprogramm der \xc3\xb6sterreichischen </b><br/>\n<b>Bundesregierung f\xc3\xbcr die Jahre </b><br/>\n<b>2013 bis 2018</b><br/>\n1<br/>\n\n<a name=2></a><b>Inhaltsverzeichnis</b><br/>\n<b>Pr\xc3\xa4ambel</b><br/>\n<b>Seite </b><br/>\n<b>3</b><br/>\n<b>Zusammenarbeit der beiden Regier
# ...

# %%
data=data.replace("<hr/>","")
data=re.sub("\<a name=.*?\/a>","",data)

# %%
data[0:1000]
# Out:
# '<!DOCTYPE html><html>\n<head>\n<title></title>\n<style type="text/css">\n<!--\n.xflip {\n    -moz-transform: scaleX(-1);\n    -webkit-transform: scaleX(-1);\n    -o-transform: scaleX(-1);\n    transform: scaleX(-1);\n    filter: fliph;\n}\n.yflip {\n    -moz-transform: scaleY(-1);\n    -webkit-transform: scaleY(-1);\n    -o-transform: scaleY(-1);\n    transform: scaleY(-1);\n    filter: flipv;\n}\n.xyflip {\n    -moz-transform: scaleX(-1) scaleY(-1);\n    -webkit-transform: scaleX(-1) scaleY(-1);\n    -o-transform: scaleX(-1) scaleY(-1);\n    transform: scaleX(-1) scaleY(-1);\n    filter: fliph + flipv;\n}\n-->\n</style>\n</head>\n<body>\n<b>Erfolgreich. \xc3\x96sterreich.</b><br/>\n<b>Arbeitsprogramm der \xc3\xb6sterreichischen </b><br/>\n<b>Bundesregierung f\xc3\xbcr die Jahre </b><br/>\n<b>2013 bis 2018</b><br/>\n\n<b>Inhaltsverzeichnis</b><br/>\n<b>Pr\xc3\xa4ambel</b><br/>\n<b>Seite </b><br/>\n<b>3</b><br/>\n<b>Zusammenarbeit der beiden Regierungsparteien</b><br/>\n<b>Seite </b>
# ...

# %%
data=data.replace("<br/>","")

# %%
data=re.sub("\s+"," ",data)

# %%
f=open("data/regierungsprogramm-2013-18-clean.html","wb")

# %%
f.write(data)

# %%
f.close()

# %%
data
# Out:
# '<!DOCTYPE html><html> <head> <title></title> <style type="text/css"> <!-- .xflip { -moz-transform: scaleX(-1); -webkit-transform: scaleX(-1); -o-transform: scaleX(-1); transform: scaleX(-1); filter: fliph; } .yflip { -moz-transform: scaleY(-1); -webkit-transform: scaleY(-1); -o-transform: scaleY(-1); transform: scaleY(-1); filter: flipv; } .xyflip { -moz-transform: scaleX(-1) scaleY(-1); -webkit-transform: scaleX(-1) scaleY(-1); -o-transform: scaleX(-1) scaleY(-1); transform: scaleX(-1) scaleY(-1); filter: fliph + flipv; } --> </style> </head> <body> <b>Erfolgreich. \xc3\x96sterreich.</b> <b>Arbeitsprogramm der \xc3\xb6sterreichischen </b> <b>Bundesregierung f\xc3\xbcr die Jahre </b> <b>2013 bis 2018</b> <b>Inhaltsverzeichnis</b> <b>Pr\xc3\xa4ambel</b> <b>Seite </b> <b>3</b> <b>Zusammenarbeit der beiden Regierungsparteien</b> <b>Seite </b> <b>5</b> <b>Wachstum und Besch\xc3\xa4ftigung f\xc3\xbcr \xc3\x96sterreich</b> <b>Seite </b> <b>6</b> <b>\xc3\x96sterreich fit f\xc3\xbcr die Zuk
# ...
